# %% [markdown]
# ## 設定

# %%
import tensorflow as tf

import tensorflow_datasets as tfds
import os

# %%
from tensorflow.keras.utils import get_file

DIRECTORY_URL = 'https://storage.googleapis.com/download.tensorflow.org/data/illiad/'
FILE_NAMES = ['cowper.txt', 'derby.txt', 'butler.txt']

for name in FILE_NAMES:
  text_dir = get_file(name, origin=DIRECTORY_URL+name)

parent_dir = os.path.dirname(text_dir)

parent_dir
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-1109770c1740> in <module>()
# ----> 1 from tensorflow.keras.utils import get_file
#       2
#       3 DIRECTORY_URL = 'https://storage.googleapis.com/download.tensorflow.org/data/illiad/'
#       4 FILE_NAMES = ['cowper.txt', 'derby.txt', 'butler.txt']
#       5
#
# /usr/local/lib/python3.7/dist-packages/keras/api/_v2/keras/__init__.py in <module>()
#       8 import sys as _sys
#       9
# ---> 10 from keras import __version__
#      11 from keras.api._v2.keras import __internal__
#      12 from keras.api._v2.keras import activations
#
# /usr/local/lib/python3.7/dist-packages/keras/__init__.py in <module>()
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# /usr/local/lib/python3.7/dist-packages/keras/models.py in <module>()
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# /usr/local/lib/python3.7/dist-packages/keras/metrics.py in <module>()
#      24
#      25 import numpy as np
# ---> 26 from keras import activations
#      27 from keras import backend
#      28 from keras.engine import base_layer
#
# /usr/local/lib/python3.7/dist-packages/keras/activations.py in <module>()
#      18
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/__init__.py in <module>()
#      22 # pylint: disable=g-bad-import-order
#      23 # pylint: disable=g-import-not-at-top
# ---> 24 from keras.engine.input_layer import Input
#      25 from keras.engine.input_layer import InputLayer
#      26 from keras.engine.input_spec import InputSpec
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/input_layer.py in <module>()
#      19 from keras import backend
#      20 from keras.distribute import distributed_training_utils
# ---> 21 from keras.engine import base_layer
#      22 from keras.engine import keras_tensor
#      23 from keras.engine import node as node_module
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in <module>()
#      38 from keras.engine import node as node_module
#      39 from keras.mixed_precision import autocast_variable
# ---> 40 from keras.mixed_precision import loss_scale_optimizer
#      41 from keras.mixed_precision import policy
#      42 from keras.saving.saved_model import layer_serialization
#
# /usr/local/lib/python3.7/dist-packages/keras/mixed_precision/loss_scale_optimizer.py in <module>()
#      16
#      17 from keras import backend
# ---> 18 from keras import optimizers
#      19 from keras.mixed_precision import loss_scale as keras_loss_scale_module
#      20 from keras.optimizer_v2 import optimizer_v2
#
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/__init__.py in <module>()
# ----> 1 from tensorflow.keras.optimizers import *
#
# /usr/local/lib/python3.7/dist-packages/keras/api/_v2/keras/optimizers/__init__.py in <module>()
#       8 import sys as _sys
#       9
# ---> 10 from keras.api._v2.keras.optimizers import schedules
#      11 from keras.optimizer_v2.adadelta import Adadelta
#      12 from keras.optimizer_v2.adagrad import Adagrad
#
# /usr/local/lib/python3.7/dist-packages/keras/api/__init__.py in <module>()
#       8 import sys as _sys
#       9
# ---> 10 from keras.api import keras
#      11
#      12 del _print_function
#
# /usr/local/lib/python3.7/dist-packages/keras/api/keras/__init__.py in <module>()
#       8 import sys as _sys
#       9
# ---> 10 from keras import __version__
#      11 from keras.api.keras import __internal__
#      12 from keras.api.keras import activations
#
# ImportError: cannot import name '__version__' from 'keras' (/usr/local/lib/python3.7/dist-packages/keras/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
