# %% [markdown]
# ## データ準備

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np

print(tf.__version__)
# Out:
# 2.5.0

# %%
imdb = keras.datasets.imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
print(f'Training entries: {len(train_data)}, labels: {len(train_labels)}')
# Out:
# Training entries: 25000, labels: 25000

# %%
train_data
# Out:
# array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
#        list([1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463, 4369, 5012, 134, 26, 4, 715, 8, 118, 1634, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 3103, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2300, 1523, 5, 647, 4, 116, 9, 35, 8163, 4, 229, 9, 340, 1322, 4, 118, 9, 4, 130, 4901, 19, 4, 1002, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 1543, 1905, 398, 4, 1649, 26, 6853, 5, 163, 11, 3215, 2, 4, 1153, 9, 194, 775, 7, 8255, 2, 349, 2637, 148, 605, 2, 8003, 15, 123, 125, 68, 2, 6853, 15, 349, 165, 4362, 98, 5, 4, 228, 9, 43, 2, 1157, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 4373, 228, 8255, 5, 2, 656, 245, 2350, 5, 4, 9837, 131, 152, 491, 18, 2, 32, 7464, 1212, 14, 9, 6, 371, 78, 22, 625, 64, 1382, 9, 8, 168, 145, 23, 4, 1690, 15, 16, 4, 1355, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95]),
#        list([1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 5974, 54, 61, 369, 13, 71, 149, 14, 22, 112, 4, 2401, 311, 12, 16, 3711, 33, 75, 43, 1829, 296, 4, 86, 320, 35, 534, 19, 263, 4821, 1301, 4, 1873, 33, 89, 78, 12, 66, 16, 4, 360, 7, 4, 58, 316, 334, 11, 4, 1716, 43, 645, 662, 8, 257, 85, 1200, 42, 1228, 2578, 83, 68, 3912, 15, 36, 165, 1539, 278, 36, 69, 2, 780, 8, 106, 14, 6905, 1338, 18, 6, 22, 12, 215, 28, 610, 40, 6, 87, 326, 23, 2300, 21, 23, 22, 12, 272, 40, 57, 31, 11, 4, 22, 47, 6, 2307, 51, 9, 170, 23, 595, 116, 595, 1352, 13, 191, 79, 638, 89, 2, 14, 9, 8, 106, 607, 624, 35, 534, 6, 227, 7, 129, 113]),
#        ...,
#        list([1, 11, 6, 230, 245, 6401, 9, 6, 1225, 446, 2, 45, 2174, 84, 8322, 4007, 21, 4, 912, 84, 2, 325, 725, 134, 2, 1715, 84, 5, 36, 28, 57, 1099, 21, 8, 140, 8, 703, 5, 2, 84, 56, 18, 1644, 14, 9, 31, 7, 4, 9406, 1209, 2295, 2, 1008, 18, 6, 20, 207, 110, 563, 12, 8, 2901, 2, 8, 97, 6, 20, 53, 4767, 74, 4, 460, 364, 1273, 29, 270, 11, 960, 108, 45, 40, 29, 2961, 395, 11, 6, 4065, 500, 7, 2, 89, 364, 70, 29, 140, 4, 64, 4780, 11, 4, 2678, 26, 178, 4, 529, 443, 2, 5, 27, 710, 117, 2, 8123, 165, 47, 84, 37, 131, 818, 14, 595, 10, 10, 61, 1242, 1209, 10, 10, 288, 2260, 1702, 34, 2901, 2, 4, 65, 496, 4, 231, 7, 790, 5, 6, 320, 234, 2766, 234, 1119, 1574, 7, 496, 4, 139, 929, 2901, 2, 7750, 5, 4241, 18, 4, 8497, 2, 250, 11, 1818, 7561, 4, 4217, 5408, 747, 1115, 372, 1890, 1006, 541, 9303, 7, 4, 59, 2, 4, 3586, 2]),
#        list([1, 1446, 7079, 69, 72, 3305, 13, 610, 930, 8, 12, 582, 23, 5, 16, 484, 685, 54, 349, 11, 4120, 2959, 45, 58, 1466, 13, 197, 12, 16, 43, 23, 2, 5, 62, 30, 145, 402, 11, 4131, 51, 575, 32, 61, 369, 71, 66, 770, 12, 1054, 75, 100, 2198, 8, 4, 105, 37, 69, 147, 712, 75, 3543, 44, 257, 390, 5, 69, 263, 514, 105, 50, 286, 1814, 23, 4, 123, 13, 161, 40, 5, 421, 4, 116, 16, 897, 13, 2, 40, 319, 5872, 112, 6700, 11, 4803, 121, 25, 70, 3468, 4, 719, 3798, 13, 18, 31, 62, 40, 8, 7200, 4, 2, 7, 14, 123, 5, 942, 25, 8, 721, 12, 145, 5, 202, 12, 160, 580, 202, 12, 6, 52, 58, 2, 92, 401, 728, 12, 39, 14, 251, 8, 15, 251, 5, 2, 12, 38, 84, 80, 124, 12, 9, 23]),
#        list([1, 17, 6, 194, 337, 7, 4, 204, 22, 45, 254, 8, 106, 14, 123, 4, 2, 270, 2, 5, 2, 2, 732, 2098, 101, 405, 39, 14, 1034, 4, 1310, 9, 115, 50, 305, 12, 47, 4, 168, 5, 235, 7, 38, 111, 699, 102, 7, 4, 4039, 9245, 9, 24, 6, 78, 1099, 17, 2345, 2, 21, 27, 9685, 6139, 5, 2, 1603, 92, 1183, 4, 1310, 7, 4, 204, 42, 97, 90, 35, 221, 109, 29, 127, 27, 118, 8, 97, 12, 157, 21, 6789, 2, 9, 6, 66, 78, 1099, 4, 631, 1191, 5, 2642, 272, 191, 1070, 6, 7585, 8, 2197, 2, 2, 544, 5, 383, 1271, 848, 1468, 2, 497, 2, 8, 1597, 8778, 2, 21, 60, 27, 239, 9, 43, 8368, 209, 405, 10, 10, 12, 764, 40, 4, 248, 20, 12, 16, 5, 174, 1791, 72, 7, 51, 6, 1739, 22, 4, 204, 131, 9])],
#       dtype=object)

# %%
train_labels
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
print('train_data.shape', train_data.shape)
print('train_labels.shape', train_labels.shape)
print('test_test.shape', test_data.shape)
print('test_labels.shape', test_labels.shape)
# Out:
# train_data.shape (25000,)
# train_labels.shape (25000,)
# test_test.shape (25000,)
# test_labels.shape (25000,)

# %%
# 単語を整数にマッピングする辞書
word_index = imdb.get_word_index()

# インデックスの最初の方は予約済み
word_index = {k:(v+3) for k,v in word_index.items()} 
word_index['<PAD>'] = 0
word_index['<START>'] = 1
word_index['<UNK>'] = 2  # unknown
word_index['<UNUSED>'] = 3

reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step

# %%
decode_review(train_data[0])
# Out:
# "<START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little boy's that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
train_data = keras.preprocessing.sequence.pad_sequences(train_data,
                                                        value=word_index["<PAD>"],
                                                        padding='post',
                                                        maxlen=256)

test_data = keras.preprocessing.sequence.pad_sequences(test_data,
                                                       value=word_index["<PAD>"],
                                                       padding='post',
                                                       maxlen=256)

# %%
len(train_data[0]), len(train_data[1])
# Out:
# (256, 256)

# %% [markdown]
# ## モデルの構築

# %%
from keras.layers import Embedding, GlobalAveragePooling1D, Dense
from keras.models import Sequential

# 入力の形式は映画レビューで使われている語彙数（10,000語）
vocab_size = 10000

model = Sequential()
model.add(Embedding(vocab_size, 16))
model.add(GlobalAveragePooling1D())
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d_6 ( (None, 16)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 4)                 68
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 160,073
# Trainable params: 160,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# 検証用データの作成
x_val = train_data[:10000]
partial_x_train = train_data[10000:]

y_val = train_labels[:10000]
partial_y_train = train_labels[10000:]

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=40,
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    verbose=1)
# Out:
# Epoch 1/40
# 30/30 [==============================] - 2s 30ms/step - loss: 0.6926 - accuracy: 0.5592 - val_loss: 0.6909 - val_accuracy: 0.6951
# Epoch 2/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.6897 - accuracy: 0.7083 - val_loss: 0.6872 - val_accuracy: 0.7265
# Epoch 3/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.6852 - accuracy: 0.7497 - val_loss: 0.6813 - val_accuracy: 0.7103
# Epoch 4/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.6782 - accuracy: 0.7341 - val_loss: 0.6729 - val_accuracy: 0.7443
# Epoch 5/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.6684 - accuracy: 0.7615 - val_loss: 0.6613 - val_accuracy: 0.7338
# Epoch 6/40
# 30/30 [==============================] - 1s 22ms/step - loss: 0.6541 - accuracy: 0.7584 - val_loss: 0.6461 - val_accuracy: 0.7661
# Epoch 7/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.6360 - accuracy: 0.7875 - val_loss: 0.6265 - val_accuracy: 0.7738
# Epoch 8/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.6134 - accuracy: 0.7975 - val_loss: 0.6035 - val_accuracy: 0.7842
# Epoch 9/40
# 30/30 [==============================] - 1s 23ms/step - loss: 0.5875 - accuracy: 0.8072 - val_loss: 0.5792 - val_accuracy: 0.7965
# Epoch 10/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.5590 - accuracy: 0.8202 - val_loss: 0.5524 - val_accuracy: 0.8001
# Epoch 11/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.5282 - accuracy: 0.8283 - val_loss: 0.5265 - val_accuracy: 0.8171
# Epoch 12/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.5034 - accuracy: 0.8378 - val_loss: 0.5003 - val_accuracy: 0.8237
# Epoch 13/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.4710 - accuracy: 0.8514 - val_loss: 0.4761 - val_accuracy: 0.8341
# Epoch 14/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.4453 - accuracy: 0.8587 - val_loss: 0.4537 - val_accuracy: 0.8391
# Epoch 15/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.4202 - accuracy: 0.8667 - val_loss: 0.4336 - val_accuracy: 0.8442
# Epoch 16/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3921 - accuracy: 0.8796 - val_loss: 0.4153 - val_accuracy: 0.8500
# Epoch 17/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3830 - accuracy: 0.8719 - val_loss: 0.4000 - val_accuracy: 0.8537
# Epoch 18/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3603 - accuracy: 0.8823 - val_loss: 0.3855 - val_accuracy: 0.8574
# Epoch 19/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3419 - accuracy: 0.8875 - val_loss: 0.3730 - val_accuracy: 0.8612
# Epoch 20/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3282 - accuracy: 0.8899 - val_loss: 0.3627 - val_accuracy: 0.8648
# Epoch 21/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3160 - accuracy: 0.8972 - val_loss: 0.3526 - val_accuracy: 0.8667
# Epoch 22/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3038 - accuracy: 0.8951 - val_loss: 0.3442 - val_accuracy: 0.8707
# Epoch 23/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2892 - accuracy: 0.9044 - val_loss: 0.3368 - val_accuracy: 0.8731
# Epoch 24/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2803 - accuracy: 0.9060 - val_loss: 0.3302 - val_accuracy: 0.8739
# Epoch 25/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2682 - accuracy: 0.9095 - val_loss: 0.3251 - val_accuracy: 0.8736
# Epoch 26/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2625 - accuracy: 0.9098 - val_loss: 0.3194 - val_accuracy: 0.8775
# Epoch 27/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2475 - accuracy: 0.9210 - val_loss: 0.3145 - val_accuracy: 0.8788
# Epoch 28/40
# 30/30 [==============================] - 1s 19ms/step - loss: 0.2475 - accuracy: 0.9155 - val_loss: 0.3109 - val_accuracy: 0.8774
# Epoch 29/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2405 - accuracy: 0.9177 - val_loss: 0.3071 - val_accuracy: 0.8785
# Epoch 30/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2335 - accuracy: 0.9213 - val_loss: 0.3037 - val_accuracy: 0.8802
# Epoch 31/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2255 - accuracy: 0.9213 - val_loss: 0.3004 - val_accuracy: 0.8812
# Epoch 32/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2135 - accuracy: 0.9303 - val_loss: 0.2978 - val_accuracy: 0.8839
# Epoch 33/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2067 - accuracy: 0.9300 - val_loss: 0.2956 - val_accuracy: 0.8822
# Epoch 34/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2023 - accuracy: 0.9321 - val_loss: 0.2938 - val_accuracy: 0.8833
# Epoch 35/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1961 - accuracy: 0.9334 - val_loss: 0.2919 - val_accuracy: 0.8832
# Epoch 36/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1962 - accuracy: 0.9335 - val_loss: 0.2907 - val_accuracy: 0.8846
# Epoch 37/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1911 - accuracy: 0.9363 - val_loss: 0.2891 - val_accuracy: 0.8845
# Epoch 38/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1852 - accuracy: 0.9398 - val_loss: 0.2884 - val_accuracy: 0.8845
# Epoch 39/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1788 - accuracy: 0.9407 - val_loss: 0.2872 - val_accuracy: 0.8847
# Epoch 40/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1723 - accuracy: 0.9455 - val_loss: 0.2867 - val_accuracy: 0.8851

# %%
results = model.evaluate(test_data,  test_labels, verbose=2)

print(results)
# Out:
# 782/782 - 1s - loss: 0.3011 - accuracy: 0.8766
# [0.30111801624298096, 0.8766000270843506]

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # 図のクリア

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
